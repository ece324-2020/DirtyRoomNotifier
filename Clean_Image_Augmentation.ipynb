# %% [markdown]
# ## **Clean Image Data Augmentation**

# %%
import numpy as np
from PIL import Image, ImageEnhance, ImageFilter
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5d04e080-4e45-4521-b0f0-fea7afd22217" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5d04e080-4e45-4521-b0f0-fea7afd22217">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 01_A1.jpg to 01_A1.jpg
# Saving 01_A2.JPG to 01_A2.JPG
# Saving 01_A3.JPG to 01_A3.JPG
# Saving 01_A4.jpg to 01_A4.jpg
# Saving 01_A5.jpg to 01_A5.jpg
# Saving 01_A6.jpg to 01_A6.jpg
# Saving 01_A7.jpg to 01_A7.jpg
# Saving 01_A8.jpg to 01_A8.jpg
# Saving 01_A9.jpg to 01_A9.jpg
# Saving 01_A10.jpg to 01_A10.jpg

# %%
# Display a random image
im1 = Image.open('01_A1.jpg')
plt.imshow(im1)

# %%
# Test the Image brightness enhancer
enhancer = ImageEnhance.Brightness(im1)

factor = 0.5 # Brightness factor
im_output = enhancer.enhance(factor)
plt.imshow(im_output)

# %%
# Import all our images

im1 = Image.open('01_A1.jpg')
im2 = Image.open('01_A2.JPG')
im3 = Image.open('01_A3.JPG')
im4 = Image.open('01_A4.jpg')
im5 = Image.open('01_A5.jpg')
im6 = Image.open('01_A6.jpg')
im7 = Image.open('01_A7.jpg')
im8 = Image.open('01_A8.jpg')
im9 = Image.open('01_A9.jpg')
im10 = Image.open('01_A10.jpg')

# %%
# Instantiate ImageEnhancer class for each image
enhancer1 = ImageEnhance.Brightness(im1)
enhancer2 = ImageEnhance.Brightness(im2)
enhancer3 = ImageEnhance.Brightness(im3)
enhancer4 = ImageEnhance.Brightness(im4)
enhancer5 = ImageEnhance.Brightness(im5)
enhancer6 = ImageEnhance.Brightness(im6)
enhancer7 = ImageEnhance.Brightness(im7)
enhancer8 = ImageEnhance.Brightness(im8)
enhancer9 = ImageEnhance.Brightness(im9)
enhancer10 = ImageEnhance.Brightness(im10)

# For each image, we want 19 other pictures with a difference brightness factor
factors = [0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1.1, 1.15, 1.2, 1.25, 1.3, 1.35, 1.4, 1.45, 1.5, 1.55]

dir_path = '/content/gdrive/My Drive/cleans_aug/'

for i in range(len(factors)):

    print('Set ', i, ' started - Factor = ', factors[i])

    out1 = enhancer1.enhance(factors[i]).save(dir_path + '0' + str(i + 2) + '_A1.jpg')
    out2 = enhancer2.enhance(factors[i]).save(dir_path + '0' + str(i + 2) + '_A2.jpg')
    out3 = enhancer3.enhance(factors[i]).save(dir_path + '0' + str(i + 2) + '_A3.jpg')
    out4 = enhancer4.enhance(factors[i]).save(dir_path + '0' + str(i + 2) + '_A4.jpg')
    out5 = enhancer5.enhance(factors[i]).save(dir_path + '0' + str(i + 2) + '_A5.jpg')
    out6 = enhancer6.enhance(factors[i]).save(dir_path + '0' + str(i + 2) + '_A6.jpg')
    out7 = enhancer7.enhance(factors[i]).save(dir_path + '0' + str(i + 2) + '_A7.jpg')
    out8 = enhancer8.enhance(factors[i]).save(dir_path + '0' + str(i + 2) + '_A8.jpg')
    out9 = enhancer9.enhance(factors[i]).save(dir_path + '0' + str(i + 2) + '_A9.jpg')
    out10 = enhancer10.enhance(factors[i]).save(dir_path + '0' + str(i + 2) + '_A10.jpg')

print("DONE: All Images saved :)")
# Out:
# Set  0  started - Factor =  0.55
# Set  1  started - Factor =  0.6
# Set  2  started - Factor =  0.65
# Set  3  started - Factor =  0.7
# Set  4  started - Factor =  0.75
# Set  5  started - Factor =  0.8
# Set  6  started - Factor =  0.85
# Set  7  started - Factor =  0.9
# Set  8  started - Factor =  0.95
# Set  9  started - Factor =  1.1
# Set  10  started - Factor =  1.15
# Set  11  started - Factor =  1.2
# Set  12  started - Factor =  1.25
# Set  13  started - Factor =  1.3
# Set  14  started - Factor =  1.35
# Set  15  started - Factor =  1.4
# Set  16  started - Factor =  1.45
# Set  17  started - Factor =  1.5
# Set  18  started - Factor =  1.55
# DONE: All Images saved :)
